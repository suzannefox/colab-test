# %% [markdown]
# <a href="https://colab.research.google.com/github/suzannefox/colab-test/blob/main/colab_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Testing, Testing

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('update in github')

# %%
print('second update')
